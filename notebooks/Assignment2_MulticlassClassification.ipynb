# %% [markdown]
# <a href="https://colab.research.google.com/github/sjkchang/CMPE255-Assignment-2/blob/master/notebooks/Assignment2_MulticlassClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret

# %%
# check installed version
import pycaret
pycaret.__version__
# Out:
# '3.0.4'

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/Datasets/255-Datasets
# %ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/Datasets/255-Datasets
#  3D-Print-Anomoly-Detection/
#  Amazon-stock-time-series.csv
#  CarPrice_Assignment.csv
# 'Credit Card Customer Data - Clustering.csv'
#  falling-elders-anomoly-detection/
#  flagged/
#  Groceries_dataset-association-rules-mining.csv
#  heartattack.csv
#  logs.log
#  Mine_Dataset.csv
#  my_first_pipeline.pkl
#  ny-traffic.csv
# 'Out-of-Sample Forecast Plot.html'
#  secondhand-car-price-regression.csv

# %%
from pycaret.datasets import get_data
data = get_data('Mine_Dataset')
# Out:
#           V         H    S  M
# 0  0.338157  0.000000  0.0  1
# 1  0.320241  0.181818  0.0  1
# 2  0.287009  0.272727  0.0  1
# 3  0.256284  0.454545  0.0  1
# 4  0.262840  0.545455  0.0  1

# %%
# import pycaret classification and init setup
from pycaret.classification import *
s = setup(data, target = 'M', session_id = 123)
# Out:
# <style type="text/css">
# #T_355a2_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_355a2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_355a2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_355a2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_355a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_355a2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_355a2_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_355a2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_355a2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_355a2_row1_col1" class="data row1 col1" >M</td>
#     </tr>
#     <tr>
#       <th id="T_355a2_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_381e2 th {
#   text-align: left;
# }
# ...

# %%
plot_model(best, plot = 'confusion_matrix')

# %%
plot_model(best, plot = 'feature')

# %%
plot_model(best, plot = 'auc')
